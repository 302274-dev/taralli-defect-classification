# %%
# BLOCCO 1 - IMPORTAZIONE LIBRERIE
# Importiamo le librerie necessarie
import os
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import time
import seaborn as sns

# ML utils
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Classificatori
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, Perceptron

# Deep learning
import tensorflow as tf
from tensorflow import keras

# %%
# BLOCCO 2 - LETTURA IMMAGINI E LABEL
# Abbiamo centralizzato la lettura del dataset: mappatura delle etichette
# da CSV, conversione delle immagini in scala di grigi e creazione delle
# matrici finali per il modello.

base_dir = Path('IndustryBiscuit/Images')
labels_csv = pd.read_csv('IndustryBiscuit/Annotations.csv')

file_to_class = dict(zip(labels_csv['file'], labels_csv['classCode']))

images, labels = [], []

for img_file in base_dir.glob("*.jpg"):
    try:
        img = Image.open(img_file).convert("L") 
        images.append(np.array(img))
        labels.append(file_to_class[img_file.name])
    except Exception as e:
        print(f"Errore su {img_file}: {e}")

X = np.stack(images)
y = np.array(labels, dtype=np.int64)

class_mapping = dict(zip(labels_csv['classCode'], labels_csv['classDescription']))
num_classes = len(class_mapping)

print("Shape immagini:", X.shape)
print("Shape labels:", y.shape)
print("Classi:", class_mapping)
# Out:
# Shape immagini: (4900, 256, 256)
# Shape labels: (4900,)
# Classi: {1: 'Defect_Shape', 2: 'Defect_Object', 3: 'Defect_Color', 0: 'Defect_No'}

# %%
# BLOCCO 3 - VISUALIZZAZIONE PRIME IMMAGINI
# Abbiamo predisposto una verifica visiva del dataset: il blocco genera 
# una griglia con le prime 9 immagini e le relative etichette descrittive, 
# permettendo di confermare a colpo d'occhio la correttezza del caricamento 
# e della mappatura delle classi.

plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X[i], cmap='gray')
    plt.title(class_mapping[y[i]])
    plt.axis("off")
plt.show()

# %%
# BLOCCO 4 - RIDIMENSIONAMENTO A 64x64 
# Abbiamo uniformato le dimensioni del dataset a 64x64 pixel e normalizzato 
# i valori cromatici nell'intervallo [0, 1]. Questa operazione garantisce 
# input costanti e facilita la convergenza durante l'addestramento.

def resize_to_64(img):
    h, w = img.shape[:2]
    y_idx = np.linspace(0, h-1, 64).round().astype(int)
    x_idx = np.linspace(0, w-1, 64).round().astype(int)
    return img[y_idx][:, x_idx]

X64 = np.stack([resize_to_64(im) for im in X])
X64 = X64.astype("float32") / 255

# Visualizza un esempio ridimensionato
id = 175
plt.imshow(X64[id], cmap='gray')
plt.title(f"Check 64x64: {class_mapping[y[id]]}")
plt.axis('off')
plt.show()

# %%
# BLOCCO 5 - TRAIN/TEST SPLIT
# Abbiamo suddiviso il dataset in set di addestramento e di test (80/20): 
# il blocco utilizza la stratificazione per garantire che le proporzioni 
# delle classi rimangano invariate tra i due gruppi, assicurando così una 
# valutazione del modello corretta e rappresentativa.

x_train, x_test, y_train, y_test = train_test_split(
    X64, y, test_size=0.2, random_state=42, stratify=y)

print('Train shape:', x_train.shape, 'Test shape:', x_test.shape)
# Out:
# Train shape: (3920, 64, 64) Test shape: (980, 64, 64)

# %%
# BLOCCO 6 - PCA + ML CLASSICI (GRAY)
# Abbiamo implementato l'estrazione delle feature tramite PCA e il sistema di 
# valutazione: il blocco riduce la dimensionalità delle immagini 64x64 in 
# scala di grigi a 100 componenti principali e definisce i tool di analisi.

def fit_pca_features_gray(X_train, n_components=100):
    N = X_train.shape[0]
    # Flattening: 64x64 = 4.096 valori per immagine
    X_flat = X_train.reshape(N, -1)
    
    # Standardizzazione: trasforma i dati per avere media 0 e varianza 1
    scaler = StandardScaler().fit(X_flat)
    X_s = scaler.transform(X_flat)
    
    # PCA per estrarre le 100 caratteristiche più significative
    pca = PCA(n_components=n_components, random_state=42).fit(X_s)
    X_pca = pca.transform(X_s)
    return X_pca, scaler, pca

def transform_pca_features_gray(X, scaler, pca):
    N = X.shape[0]
    X_flat = X.reshape(N, -1)
    X_s = scaler.transform(X_flat)
    return pca.transform(X_s)

# Trasformazione dei dati (Usa x_train 64x64 in scala di grigi)
X_train_feat, scaler, pca = fit_pca_features_gray(x_train, n_components=100)
X_test_feat = transform_pca_features_gray(x_test, scaler, pca)

print("Train features:", X_train_feat.shape)
print("Test features:", X_test_feat.shape)

# Strumenti di Analisi e Valutazione
results = []

def evaluate_and_save(name, model, X_test_feat, y_test, y_pred, best_params=None, fit_time=None):
    acc = accuracy_score(y_test, y_pred)
    macro_f1 = f1_score(y_test, y_pred, average='macro')
    macro_prec = precision_score(y_test, y_pred, average='macro')
    macro_rec = recall_score(y_test, y_pred, average='macro')

    print(f"\n===== {name} =====")
    print(f"Accuracy:        {acc:.4f}")
    print(f"Precision-macro: {macro_prec:.4f}")
    print(f"Recall-macro:    {macro_rec:.4f}")
    print(f"F1-macro:       {macro_f1:.4f}")
    print(f"Best params:     {best_params}")
    if fit_time:
        print(f"Fit time:        {fit_time:.2f}s")

    results.append({
        "model": name, "accuracy": acc, "macro_f1": macro_f1,
        "macro_precision": macro_prec, "macro_recall": macro_rec,
        "best_params": best_params, "fit_time_sec": fit_time
    })

def plot_cm(model_name, y_true, y_pred, class_mapping):
    # Recupera i nomi delle classi nell'ordine numerico corretto
    labels = [class_mapping[i] for i in sorted(class_mapping.keys())]
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(f"Confusion Matrix - {model_name} 64x64 Scala di Grigi")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
# Out:
# Train features: (3920, 100)
# Test features: (980, 100)

# %%
# BLOCCO 7 - GRID SEARCH + KNN
# Abbiamo eseguito l'ottimizzazione del classificatore KNN sui dati 64x64 
# in scala di grigi: il blocco cerca i migliori iperparametri tramite 
# Grid Search e valuta il modello finale su metriche macro e matrici di confusione.

# Configurazione della griglia di ricerca per KNN
param_grid = {
    "n_neighbors": [3, 5, 7], 
    "metric": ["euclidean", "manhattan"]
}

gs = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5, scoring="accuracy", n_jobs=-1)

t0 = time.time()
gs.fit(X_train_feat, y_train)
t1 = time.time()

# Predizione sul test set con il miglior modello trovato
y_pred = gs.best_estimator_.predict(X_test_feat)

# Valutazione e salvataggio dei risultati (usando le funzioni del Blocco 6)
evaluate_and_save("KNN", gs.best_estimator_, X_test_feat, y_test, y_pred, gs.best_params_, t1-t0)

# Visualizzazione grafica degli errori
plot_cm("KNN", y_test, y_pred, class_mapping)
# Out:
# ===== KNN =====
# Accuracy:        0.7816
# Precision-macro: 0.8110
# Recall-macro:    0.6595
# F1-macro:       0.6866
# Best params:     {'metric': 'euclidean', 'n_neighbors': 3}
# Fit time:        3.06s

# %%
# BLOCCO 8 - GRID SEARCH + DECISION TREE
# Abbiamo ottimizzato l'albero di decisione: il blocco cerca i parametri 
# migliori per profondità e potatura (pruning), analizzando poi le 
# performance tramite metriche macro e matrice di confusione.

# Configurazione della griglia di ricerca per Decision Tree
param_grid = {
    "criterion": ["gini", "entropy"], 
    "max_depth": [None, 5, 10, 20], 
    "ccp_alpha": [0.0, 0.001, 0.005]
}

gs = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=5, scoring="accuracy", n_jobs=-1)

t0 = time.time()
gs.fit(X_train_feat, y_train)
t1 = time.time()

# Predizione sul test set con il miglior modello trovato
y_pred = gs.best_estimator_.predict(X_test_feat)

# Valutazione completa con Accuracy, Precision, Recall e F1-macro
evaluate_and_save("DecisionTree", gs.best_estimator_, X_test_feat, y_test, y_pred, gs.best_params_, t1-t0)

# Generazione della matrice di confusione
plot_cm("DecisionTree", y_test, y_pred, class_mapping)
# Out:
# ===== DecisionTree =====
# Accuracy:        0.7500
# Precision-macro: 0.7210
# Recall-macro:    0.6708
# F1-macro:       0.6853
# Best params:     {'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 10}
# Fit time:        7.75s

# %%
# BLOCCO 9 - GRID SEARCH + LOGISTIC REGRESSION
# Abbiamo ottimizzato la Logistic Regression sui dati 64x64 in scala di grigi: 
# il blocco cerca il miglior parametro di regolarizzazione (C) e valuta 
# il modello finale analizzando la precisione e la matrice di confusione.

# Configurazione della griglia di ricerca per Logistic Regression
param_grid = {
    "C": [0.1, 1, 10], 
    "solver": ["lbfgs"], 
    "penalty": ["l2"], 
    "max_iter": [1000]
}

gs = GridSearchCV(LogisticRegression(random_state=42), param_grid, cv=5, scoring="accuracy", n_jobs=-1)

t0 = time.time()
gs.fit(X_train_feat, y_train)
t1 = time.time()

# Predizione sul test set con il miglior modello trovato
y_pred = gs.best_estimator_.predict(X_test_feat)

# Valutazione completa (Accuracy, Precision, Recall, F1-macro)
evaluate_and_save("LogisticRegression", gs.best_estimator_, X_test_feat, y_test, y_pred, gs.best_params_, t1-t0)

# Generazione della matrice di confusione
plot_cm("LogisticRegression", y_test, y_pred, class_mapping)
# Out:
# ===== LogisticRegression =====
# Accuracy:        0.6684
# Precision-macro: 0.6381
# Recall-macro:    0.5963
# F1-macro:       0.6125
# Best params:     {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'lbfgs'}
# Fit time:        0.78s

# %%
# BLOCCO 10 - GRID SEARCH + PERCEPTRON
# Abbiamo implementato il Perceptron sui dati 64x64 in scala di grigi: il blocco 
# sfrutta la risoluzione aumentata per identificare i tratti geometrici lineari 
# che definiscono la qualità del biscotto, monitorando precisione e recall 
# per ogni classe analizzata.

param_grid = {"alpha": [1e-4, 1e-3, 1e-2], "penalty": [None, "l2"], "max_iter": [1000]}
gs = GridSearchCV(Perceptron(random_state=42), param_grid, cv=5, scoring="accuracy", n_jobs=-1)

t0 = time.time()
gs.fit(X_train_feat, y_train)
t1 = time.time()

y_pred = gs.best_estimator_.predict(X_test_feat)

evaluate_and_save("Perceptron", gs.best_estimator_, X_test_feat, y_test, y_pred, gs.best_params_, t1-t0)
plot_cm("Perceptron", y_test, y_pred, class_mapping)
# Out:
# ===== Perceptron =====
# Accuracy:        0.5071
# Precision-macro: 0.4539
# Recall-macro:    0.4664
# F1-macro:       0.4546
# Best params:     {'alpha': 0.0001, 'max_iter': 1000, 'penalty': 'l2'}
# Fit time:        0.33s

# %%
# Risultati finali modelli classici
df_results = pd.DataFrame(results).sort_values("accuracy", ascending=False)
print("\n===== RISULTATI CLASSICI =====")
print(df_results.to_string(index=False))
# Out:
# ===== RISULTATI CLASSICI =====
#              model  accuracy  macro_f1  macro_precision  macro_recall                                                      best_params  fit_time_sec
#                KNN  0.781633  0.686597         0.810953      0.659462                        {'metric': 'euclidean', 'n_neighbors': 3}      3.060281
#       DecisionTree  0.750000  0.685296         0.720993      0.670831         {'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 10}      7.754865
# LogisticRegression  0.668367  0.612520         0.638091      0.596323 {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'lbfgs'}      0.778837
#         Perceptron  0.507143  0.454583         0.453893      0.466437             {'alpha': 0.0001, 'max_iter': 1000, 'penalty': 'l2'}      0.330080

# %%
# BLOCCO 11 - CNN
# Abbiamo ottimizzato la CNN per immagini 64x64 in scala di grigi: 
# il modello analizza le texture e i bordi ad alta risoluzione, imparando 
# a classificare i prodotti attraverso una gerarchia di filtri convoluzionali 
# che estraggono le caratteristiche strutturali più rilevanti in assenza 
# di colore.

input_shape = (64,64,1)
model = keras.Sequential([
    keras.layers.Input(shape=input_shape),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(128,(3,3),activation='relu'),
    keras.layers.Conv2D(128,(3,3),activation='relu'),
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]

history = model.fit(x_train, y_train, epochs=20, validation_split=0.2, callbacks=callbacks)

# Storia training
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.show()

# Predict
predictions = model.predict(x_test)
cpredictions = [np.argmax(p) for p in predictions]

# Griglia immagini predizioni
plt.figure(figsize=(12,12))
for i in range(1,26):
    img = x_test[-i]
    plt.subplot(5,5,i)
    plt.imshow(img, cmap='gray')
    plt.title(f"True: {class_mapping[y_test[-i]]}\nPred: {class_mapping[cpredictions[-i]]}", fontsize=8)
    plt.axis('off')
plt.tight_layout()
plt.show()

# Confusion matrix CNN
label_names = [class_mapping[i] for i in range(num_classes)]
cm = confusion_matrix(y_test, cpredictions)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix CNN 64x64 Scala di Grigi')
plt.show()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 62, 62, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 26, 26, 128)    │       147,584 │
# ...
